# %% [markdown]
# <a href="https://colab.research.google.com/github/Teslamit/yolov5_colour_mask_detection/blob/main/SCAAI_yolov5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Checking the GPU

# %%
# !nvidia-smi
# Out:
# Fri Feb  5 11:45:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Mounting the Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Checking the present working directory

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# Changing the path to the Drive Mounted

# %%
# %cd /content/drive/MyDrive/mask
# Out:
# /content/drive/MyDrive/mask

# %% [markdown]
# Unzip the File

# %%
# !unzip "/content/drive/MyDrive/mask/mask (3).zip" -d "/content/drive/MyDrive/mask"
# Out:
# Archive:  /content/drive/MyDrive/mask/mask (3).zip
#    creating: /content/drive/MyDrive/mask/mask/test/
#    creating: /content/drive/MyDrive/mask/mask/test/images/
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0003.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0197.png
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0212.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0451.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0470.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0614.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0626.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/0743.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/1.jpeg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/10.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/100.jpg
#   inflating: /content/drive/MyDrive/mask/mask/test/images/104.jpg
# ...

# %% [markdown]
# Downloading the yolov5 Algorithm

# %%
# !git clone https://github.com/ultralytics/yolov5  
# !pip install -U -r yolov5/requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 4646 (delta 5), reused 9 (delta 4), pack-reused 4629
# Receiving objects: 100% (4646/4646), 7.47 MiB | 11.73 MiB/s, done.
# Resolving deltas: 100% (3165/3165), done.
# Requirement already up-to-date: Cython in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 4)) (0.29.21)
# ...
#      |████████████████████████████████| 11.5MB 242kB/s
# Requirement already up-to-date: numpy>=1.18.5 in /usr/local/lib/python3.6/dist-packages (from -r yolov5/requirements.txt (line 6)) (1.19.5)
# ...
#      |████████████████████████████████| 50.4MB 53kB/s
# ...
#      |████████████████████████████████| 2.2MB 47.2MB/s
# ...
#      |████████████████████████████████| 645kB 49.7MB/s
# ...
#      |████████████████████████████████| 25.9MB 148kB/s
# ...

# %% [markdown]
# Download yolov5 algorithm configuration file

# %%
# !wget "https://raw.githubusercontent.com/offsouza/yolov5_face_mask_detection/master/mask_yolov5s.yaml" -O /content/drive/MyDrive/mask/yolov5/mask_yolov5s.yaml
# Out:
# --2021-02-05 11:53:04--  https://raw.githubusercontent.com/offsouza/yolov5_face_mask_detection/master/mask_yolov5s.yaml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1455 (1.4K) [text/plain]
# Saving to: ‘/content/drive/MyDrive/mask/yolov5/mask_yolov5s.yaml’
#
# /content/drive/MyDr 100%[===================>]   1.42K  --.-KB/s    in 0.001s
#
# 2021-02-05 11:53:05 (1.68 MB/s) - ‘/content/drive/MyDrive/mask/yolov5/mask_yolov5s.yaml’ saved [1455/1455]

# %% [markdown]
# Train the algorIthm on face mask dataset:

# %%
# %cd /content/drive/MyDrive/mask/yolov5
# !python /content/drive/MyDrive/mask/yolov5/train.py --img 416 --batch 16 --epochs 350 --data '/content/drive/MyDrive/mask/data.yaml' --cfg /content/drive/MyDrive/mask/yolov5/mask_yolov5s.yaml --weights '' --name mask_yolov5s_results --nosave --cache
# Out:
# /content/drive/MyDrive/mask/yolov5
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# YOLOv5 v4.0-63-g73a0669 torch 1.7.1 CPU
#
# ...

# %% [markdown]
# Perform Prediction for the Trained Model

# %%
# %cd /content/drive/MyDrive/mask/yolov5
# !python detect.py --weights /content/drive/MyDrive/mask/yolov5/runs/train/mask_yolov5s_results/weights/last.pt --img 416 --source /content/drive/MyDrive/mask/mask/test/images --save-txt
# Out:
# /content/drive/MyDrive/mask/yolov5
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.25, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=True, source='/content/drive/MyDrive/mask/mask/test/images', update=False, view_img=False, weights=['/content/drive/MyDrive/mask/yolov5/runs/train/mask_yolov5s_results/weights/last.pt'])
# /usr/local/lib/python3.6/dist-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 10010). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# ...
